# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'a', 'term', 'of', 'term', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.329428
# Nearest to is: azad, dalton, fida, mcmaster, muscovy, rsc, pedantic, dniester,
# Nearest to zero: estonian, radiate, ishtar, examinations, dillon, community, clonic, hers,
# Nearest to his: bertrand, flourishing, skilful, pristine, composed, purposes, zy, surprisingly,
# Nearest to some: ecmascript, capitalists, governed, elegy, heston, kinsmen, unexplored, altair,
# Nearest to state: hopelessly, brutus, callahan, finnic, bosco, elevates, trax, incommunicado,
# Nearest to he: commonality, straps, expressive, specialties, rescheduled, administered, govt, idi,
# Nearest to d: urls, blanton, anywhere, belongs, naia, elizabethan, holstein, pauling,
# Nearest to only: autoroute, hsv, gazing, ministries, quine, quartier, hexagrams, gaeltacht,
# Nearest to states: accents, transport, scalloped, stables, hominidae, aerodynamic, tenacity, subiaco,
# Nearest to no: galileo, wordperfect, heeled, packaged, algardi, maarten, attila, dea,
# Nearest to had: test, daemons, refund, multiparty, methodius, incumbent, monarchist, geoffrey,
# Nearest to for: minorities, artaxerxes, cfp, shona, detonating, launching, versa, richards,
# Nearest to all: dispelling, castiglione, forester, mission, alexandre, bowled, graphically, clades,
# Nearest to b: astonishingly, hungarians, bede, blot, joanie, essex, training, humidity,
# Nearest to see: jammed, resurrecting, matti, stillborn, telemann, urinating, borrowings, asleep,
# Nearest to often: sprinter, educate, villeneuve, astronomically, tasman, melee, incursion, christological,
# Average loss at step 2000: 4.364759
# Average loss at step 4000: 3.862939
# Average loss at step 6000: 3.793912
# Average loss at step 8000: 3.689519
# Average loss at step 10000: 3.614173
# Nearest to is: was, are, has, saturdays, but, liao, polytechnical, raaf,
# Nearest to zero: nine, seven, six, five, eight, three, four, two,
# Nearest to his: the, their, s, her, its, pir, southerner, husserl,
# Nearest to some: many, unexplored, upwards, carmel, limburgish, dedekind, other, jesuits,
# Nearest to state: hopelessly, bosco, elevates, vibrio, scaly, callahan, alkanes, incommunicado,
# Nearest to he: it, she, they, there, commonality, who, never, specialties,
# Nearest to d: blanton, paths, pauling, gene, microbats, urls, silo, naia,
# Nearest to only: einer, currently, quartier, telecasts, hsv, autoroute, inconsistency, intolerable,
# Nearest to states: encompasses, libertarian, scalloped, poole, materialism, bother, tenacity, brassicaceae,
# Nearest to no: codd, crew, it, higher, orthodoxy, mundo, theophoric, written,
# Nearest to had: has, have, was, were, carbonaceous, competency, searchable, totalitarian,
# Nearest to for: matriculation, in, cfp, with, riverfront, of, kissing, cohn,
# Nearest to all: contending, ventspils, sarai, dispelling, pseudonyms, cop, sofie, forester,
# Nearest to b: blot, navarro, lest, essex, users, tuatha, imaged, hungarians,
# Nearest to see: jammed, surprisingly, animism, branden, noted, flooded, landmasses, atchison,
# Nearest to often: which, sprinter, also, important, educate, commonly, horizons, it,
# Average loss at step 12000: 3.604664
# Average loss at step 14000: 3.572295
# Average loss at step 16000: 3.417164
# Average loss at step 18000: 3.456331
# Average loss at step 20000: 3.545751
# Nearest to is: was, has, are, polytechnical, icosidodecahedron, lucilla, be, describes,
# Nearest to zero: five, six, seven, four, nine, eight, three, two,
# Nearest to his: their, her, its, our, the, gainesville, this, crippling,
# Nearest to some: many, these, all, their, other, most, unexplored, any,
# Nearest to state: vibrio, bosco, einstein, owners, injector, hopelessly, elevates, brutus,
# Nearest to he: it, she, they, who, never, there, commonality, bes,
# Nearest to d: b, blanton, paths, cse, pauling, pianist, islanders, conics,
# Nearest to only: currently, cts, quartier, plumage, gaeltacht, telecasts, auvergne, intolerable,
# Nearest to states: libertarian, poole, encompasses, brassicaceae, cameos, tenacity, liliales, scalloped,
# Nearest to no: homilies, generally, codd, theophoric, sprouts, it, this, pep,
# Nearest to had: has, have, was, were, having, samyaksam, searchable, took,
# Nearest to for: by, with, matriculation, osman, and, kissing, after, of,
# Nearest to all: some, many, any, these, ponty, contending, sulla, lens,
# Nearest to b: d, blot, fromm, tuatha, prosthetics, essex, imaged, hustler,
# Nearest to see: surprisingly, jammed, branden, animism, atchison, nitride, medalist, pilate,
# Nearest to often: commonly, also, which, generally, sprinter, sometimes, who, it,
# Average loss at step 22000: 3.501652
# Average loss at step 24000: 3.488678
# Average loss at step 26000: 3.483911
# Average loss at step 28000: 3.482981
# Average loss at step 30000: 3.498942
# Nearest to is: was, has, are, does, were, describes, while, okay,
# Nearest to zero: five, eight, four, seven, six, nine, three, two,
# Nearest to his: her, their, its, s, the, our, this, a,
# Nearest to some: many, these, several, all, their, any, most, unexplored,
# Nearest to state: vibrio, bosco, brutus, owners, generator, acquiring, behaviors, alkanes,
# Nearest to he: it, she, they, who, there, never, commonality, bes,
# Nearest to d: b, paths, conics, pianist, silo, blanton, gene, cse,
# Nearest to only: currently, telecasts, pagerank, it, plumage, judge, steyr, cantus,
# Nearest to states: libertarian, encompasses, tenacity, poole, rio, cameos, purdue, liliales,
# Nearest to no: still, a, not, codd, persistently, any, sprouts, dickinson,
# Nearest to had: has, have, was, having, were, since, samyaksam, is,
# Nearest to for: when, with, after, of, matriculation, against, osman, on,
# Nearest to all: some, these, many, any, jvm, contending, lens, nationhood,
# Nearest to b: d, imaged, potters, diameter, fromm, prosthetics, salting, blot,
# Nearest to see: grandpa, surprisingly, include, medalist, lithuanians, nitride, multipart, flooded,
# Nearest to often: commonly, generally, sometimes, also, usually, frequently, important, never,
# Average loss at step 32000: 3.503575
# Average loss at step 34000: 3.493897
# Average loss at step 36000: 3.456618
# Average loss at step 38000: 3.301250
# Average loss at step 40000: 3.427452
# Nearest to is: was, has, are, describes, oceanographic, be, lucilla, does,
# Nearest to zero: five, seven, nine, eight, six, four, three, two,
# Nearest to his: their, her, its, the, s, our, whose, aeschylus,
# Nearest to some: many, these, several, any, their, most, unexplored, all,
# Nearest to state: vibrio, bosco, brutus, government, breads, acquiring, owners, behaviors,
# Nearest to he: she, it, they, who, there, never, i, we,
# Nearest to d: b, UNK, blanton, k, islanders, cse, ecmascript, conics,
# Nearest to only: currently, telecasts, cantus, it, first, amoeboids, plumage, archie,
# Nearest to states: libertarian, countries, byron, encompasses, rio, kingdom, purdue, brassicaceae,
# Nearest to no: any, not, a, still, persistently, codd, there, maximal,
# Nearest to had: has, have, was, were, having, since, samyaksam, wanted,
# Nearest to for: entrepot, matriculation, when, in, against, osman, with, westport,
# Nearest to all: these, every, any, many, some, aids, nationhood, several,
# Nearest to b: d, j, c, f, potters, r, h, coptic,
# Nearest to see: include, list, devoutly, animism, medalist, multipart, grandpa, assassinating,
# Nearest to often: commonly, sometimes, generally, usually, also, frequently, which, typically,
# Average loss at step 42000: 3.432841
# Average loss at step 44000: 3.456401
# Average loss at step 46000: 3.455292
# Average loss at step 48000: 3.357805
# Average loss at step 50000: 3.389342
# Nearest to is: was, are, has, contains, vaporized, be, polytechnical, describes,
# Nearest to zero: five, seven, six, eight, nine, four, three, two,
# Nearest to his: their, her, its, our, the, my, whose, realization,
# Nearest to some: many, these, several, most, other, their, unexplored, those,
# Nearest to state: vibrio, bosco, acquiring, government, brutus, foreign, microbial, behaviors,
# Nearest to he: she, it, they, there, who, never, alignments, i,
# Nearest to d: b, conics, k, cse, ecmascript, anywhere, blanton, islanders,
# Nearest to only: cts, cantus, first, telecasts, currently, judge, ghulam, shelled,
# Nearest to states: kingdom, byron, purdue, libertarian, encompasses, nations, hydrodynamic, countries,
# Nearest to no: any, persistently, a, afc, pedestrian, generally, tournaments, still,
# Nearest to had: has, have, having, was, were, samyaksam, rejuvenation, been,
# Nearest to for: matriculation, guarani, against, nis, entrepot, while, on, fraenkel,
# Nearest to all: every, many, any, nationhood, each, some, both, these,
# Nearest to b: d, f, c, zseries, potters, h, j, skylab,
# Nearest to see: list, include, devoutly, grandpa, corso, according, medalist, multipart,
# Nearest to often: sometimes, generally, commonly, usually, frequently, now, also, typically,
# Average loss at step 52000: 3.434870
# Average loss at step 54000: 3.427942
# Average loss at step 56000: 3.442035
# Average loss at step 58000: 3.396047
# Average loss at step 60000: 3.396475
# Nearest to is: was, has, are, does, describes, implies, contains, lucilla,
# Nearest to zero: five, four, six, eight, seven, nine, three, two,
# Nearest to his: her, their, its, our, my, your, the, brecht,
# Nearest to some: many, several, these, all, numerous, any, most, this,
# Nearest to state: acquiring, government, vibrio, bosco, magnificent, brutus, generator, foreign,
# Nearest to he: she, it, they, who, there, never, eventually, we,
# Nearest to d: b, k, ecmascript, cse, anywhere, learns, c, pernambuco,
# Nearest to only: cts, first, ghulam, telecasts, but, cantus, archie, calderas,
# Nearest to states: kingdom, countries, nations, codd, libertarian, byron, defence, purdue,
# Nearest to no: any, a, afc, pedestrian, tournaments, persistently, flashy, johan,
# Nearest to had: has, have, was, having, wanted, were, samyaksam, been,
# Nearest to for: of, matriculation, when, including, if, and, telescopic, entrepot,
# Nearest to all: some, any, every, many, those, these, several, nationhood,
# Nearest to b: d, c, h, f, m, zseries, pat, p,
# Nearest to see: list, include, according, including, devoutly, external, can, includes,
# Nearest to often: sometimes, usually, commonly, generally, frequently, typically, also, now,
# Average loss at step 62000: 3.235969
# Average loss at step 64000: 3.252550
# Average loss at step 66000: 3.403264
# Average loss at step 68000: 3.395068
# Average loss at step 70000: 3.357468
# Nearest to is: was, has, are, be, contains, although, lucilla, oceanographic,
# Nearest to zero: five, four, six, eight, seven, nine, three, two,
# Nearest to his: her, their, its, our, my, your, the, whose,
# Nearest to some: many, several, all, these, any, those, various, both,
# Nearest to state: government, national, states, city, acquiring, generator, vibrio, republica,
# Nearest to he: she, it, they, there, who, never, we, eventually,
# Nearest to d: b, k, ecmascript, cse, f, r, conics, learns,
# Nearest to only: ghulam, easily, always, arrive, cts, moveable, cantus, first,
# Nearest to states: kingdom, nations, countries, byron, libertarian, bosco, codd, state,
# Nearest to no: any, than, little, afc, generally, still, tournaments, pedestrian,
# Nearest to had: has, have, was, having, were, recently, wanted, samyaksam,
# Nearest to for: guarani, against, to, if, in, after, entrepot, including,
# Nearest to all: some, many, every, any, these, various, several, those,
# Nearest to b: d, f, h, n, zseries, r, p, pat,
# Nearest to see: include, list, devoutly, according, corso, including, multipart, flooded,
# Nearest to often: sometimes, usually, commonly, generally, frequently, typically, now, also,
# Average loss at step 72000: 3.374118
# Average loss at step 74000: 3.349226
# Average loss at step 76000: 3.314289
# Average loss at step 78000: 3.354086
# Average loss at step 80000: 3.379320
# Nearest to is: was, has, are, although, contains, polytechnical, describes, includes,
# Nearest to zero: five, six, seven, eight, three, four, nine, two,
# Nearest to his: her, their, its, my, our, your, whose, the,
# Nearest to some: many, several, most, these, certain, various, any, all,
# Nearest to state: government, city, generator, lord, bosco, vocabulary, national, magnificent,
# Nearest to he: she, it, they, there, who, eventually, never, we,
# Nearest to d: b, f, cse, k, speckled, de, learns, conics,
# Nearest to only: easily, ghulam, always, actually, arrive, naxos, until, even,
# Nearest to states: kingdom, nations, countries, byron, purdue, codd, bosco, calming,
# Nearest to no: little, any, circumcisions, persistently, houser, flashy, pipes, torture,
# Nearest to had: has, have, were, having, was, wanted, recently, simulcast,
# Nearest to for: technologically, nis, guarani, reminding, carly, when, against, entrepot,
# Nearest to all: every, both, many, any, various, some, several, those,
# Nearest to b: d, c, f, zseries, pat, r, aoun, h,
# Nearest to see: include, according, list, devoutly, including, prizes, external, known,
# Nearest to often: sometimes, usually, commonly, generally, typically, frequently, now, still,
# Average loss at step 82000: 3.410827
# Average loss at step 84000: 3.413230
# Average loss at step 86000: 3.387139
# Average loss at step 88000: 3.351863
# Average loss at step 90000: 3.365462
# Nearest to is: was, has, are, contains, be, although, requires, becomes,
# Nearest to zero: five, eight, seven, six, four, three, nine, two,
# Nearest to his: her, their, its, your, my, our, the, s,
# Nearest to some: many, several, these, most, all, certain, any, both,
# Nearest to state: city, government, national, gimlin, generator, bosco, vibrio, magnificent,
# Nearest to he: she, it, they, there, who, we, eventually, never,
# Nearest to d: b, cse, f, paths, id, speckled, philippians, ipsec,
# Nearest to only: triumphant, even, actually, naxos, still, currently, fatale, holley,
# Nearest to states: kingdom, nations, us, codd, countries, defence, purdue, subservient,
# Nearest to no: any, little, circumcisions, persistently, a, sappho, tournaments, flashy,
# Nearest to had: has, have, was, were, having, continued, since, wanted,
# Nearest to for: entrepot, after, of, against, nis, guarani, without, when,
# Nearest to all: many, some, every, both, several, these, various, nationhood,
# Nearest to b: d, f, c, r, zseries, h, pat, n,
# Nearest to see: list, prizes, devoutly, include, references, according, external, preserving,
# Nearest to often: sometimes, usually, commonly, generally, frequently, typically, also, now,
# Average loss at step 92000: 3.398405
# Average loss at step 94000: 3.253347
# Average loss at step 96000: 3.358158
# Average loss at step 98000: 3.240420
# Average loss at step 100000: 3.356600
# Nearest to is: was, has, contains, became, becomes, does, are, describes,
# Nearest to zero: five, eight, four, six, seven, nine, three, two,
# Nearest to his: her, their, its, my, our, your, the, s,
# Nearest to some: many, several, these, any, certain, most, their, ecsc,
# Nearest to state: city, lord, gimlin, vibrio, bosco, national, government, generator,
# Nearest to he: she, it, they, there, who, we, never, expressionism,
# Nearest to d: b, c, philippians, r, paths, f, id, cse,
# Nearest to only: actually, even, cabot, still, infuriated, naxos, not, currently,
# Nearest to states: kingdom, nations, us, codd, byron, subservient, countries, hydrodynamic,
# Nearest to no: any, little, circumcisions, persistently, gupta, only, astronautics, constantly,
# Nearest to had: has, have, was, having, were, since, wanted, would,
# Nearest to for: after, entrepot, when, without, guarani, if, before, against,
# Nearest to all: every, various, many, several, these, any, some, those,
# Nearest to b: d, c, harold, potters, f, pat, comedian, fromm,
# Nearest to see: list, includes, references, external, devoutly, include, according, refers,
# Nearest to often: sometimes, usually, commonly, generally, frequently, typically, now, also,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, window):
  global data_index
  span = 2 * window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, window = window)
    print('\n with window = %d:' % (window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
#  with window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
#  with window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
window = 2 # How many words to consider left and right.
#num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embed, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.670341
# Nearest to was: milgrom, aidan, navigators, joost, chardin, esau, asoka, christians,
# Nearest to years: force, designing, irrelevant, gees, del, transoxiana, installing, spire,
# Nearest to he: blister, diarrhoea, verizon, byline, flambards, umayyads, meteoric, suspense,
# Nearest to were: warped, thugs, jeffries, doubled, wanderers, ooze, costs, gana,
# Nearest to during: yucat, upscale, vancouver, schoolhouse, bipm, fisheries, fascists, triton,
# Nearest to may: renounces, cubical, participated, maha, lomo, ayub, respectively, decreased,
# Nearest to other: synoptic, realistically, decentralized, precisely, silmarillion, ascertain, valery, repression,
# Nearest to d: engines, argyll, arabia, bowhunting, frisbee, rium, fets, harrington,
# Nearest to this: rulemaking, inflationary, claims, intimidation, thickly, undue, overview, kramer,
# Nearest to by: exhortations, bolstering, dinoflagellates, upheaval, ajmer, published, cripps, barge,
# Nearest to state: complain, habilis, hamitic, tabloid, archaeologist, imitative, thick, newer,
# Nearest to history: stacking, classroom, chrysler, resorting, connectedness, plastic, perfume, expert,
# Nearest to called: heydrich, administratively, siwa, reproach, hydroponics, claimant, boulders, secretly,
# Nearest to world: exercising, installment, drains, gdansk, diamondbacks, idealistic, borg, businesses,
# Nearest to they: medell, expands, aladdin, abercorn, dualities, consumers, immune, endosperm,
# Nearest to but: declination, ssc, permissive, rebels, somers, visually, minsky, degrades,
# Average loss at step 2000: 4.589253
# Average loss at step 4000: 3.921970
# Average loss at step 6000: 3.717726
# Average loss at step 8000: 3.523788
# Average loss at step 10000: 3.473587
# Nearest to was: is, were, became, had, has, are, dogg, borgir,
# Nearest to years: del, bei, economists, designing, playmate, days, loren, lastnode,
# Nearest to he: it, she, they, lawson, ergonomics, subdisciplines, unrounded, musings,
# Nearest to were: are, was, had, is, anglorum, cogency, pyongyang, minimalism,
# Nearest to during: in, orchestra, kettering, after, cummings, caravan, wholeheartedly, surrogate,
# Nearest to may: can, would, could, will, must, should, might, to,
# Nearest to other: many, several, zur, more, various, closing, wallonia, some,
# Nearest to d: b, progs, mucous, lucas, multilingual, furnishings, antietam, leyte,
# Nearest to this: what, it, a, any, evangelicalism, no, the, daniell,
# Nearest to by: hermaphrodite, copley, having, modelling, aoun, upu, mandolins, have,
# Nearest to state: national, assembly, habilis, aziz, plains, nathan, jetty, sly,
# Nearest to history: lexikon, inject, list, destruction, simplest, fluorescent, northeast, devising,
# Nearest to called: used, corvinus, perversion, hamburgers, considered, enlightenment, anacreon, accordion,
# Nearest to world: cakes, nayla, breakers, vietnam, drains, tongue, thereupon, second,
# Nearest to they: he, we, there, it, she, amps, you, lap,
# Nearest to but: and, which, calif, bonanza, although, abruzzo, charitable, alamein,
# Average loss at step 12000: 3.487318
# Average loss at step 14000: 3.439513
# Average loss at step 16000: 3.436185
# Average loss at step 18000: 3.409023
# Average loss at step 20000: 3.217435
# Nearest to was: is, were, became, are, has, had, harpsichords, chased,
# Nearest to years: days, months, centuries, decades, economists, year, times, biqa,
# Nearest to he: she, it, who, they, materialized, isaak, cnt, prescribes,
# Nearest to were: are, was, is, include, being, became, have, had,
# Nearest to during: in, before, at, after, throughout, over, until, since,
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Nearest to other: both, different, various, more, others, iud, governorates, modernist,
# Nearest to d: b, leyte, lowry, obligated, tentacle, elaine, typed, pb,
# Nearest to this: which, it, that, another, a, ncos, the, what,
# Nearest to by: under, fleeting, eradicated, among, clip, deoxyribonucleic, paste, esr,
# Nearest to state: assembly, latitudes, qassam, aachen, hectic, government, archaeologist, poe,
# Nearest to history: devising, lexikon, iy, pembroke, inject, list, variety, simplest,
# Nearest to called: known, but, named, considered, drive, used, see, vineyards,
# Nearest to world: vietnam, cakes, hirsch, garter, peer, rib, sedation, sheng,
# Nearest to they: we, you, he, there, these, spill, humans, solent,
# Nearest to but: however, although, called, though, bethe, while, heine, manichaeism,
# Average loss at step 22000: 3.359287
# Average loss at step 24000: 3.297279
# Average loss at step 26000: 3.255562
# Average loss at step 28000: 3.279004
# Average loss at step 30000: 3.223377
# Nearest to was: is, became, were, had, are, becomes, makes, remained,
# Nearest to years: days, decades, months, year, centuries, economists, times, weeks,
# Nearest to he: she, it, they, gob, immense, specifying, him, rnzaf,
# Nearest to were: are, was, is, being, had, include, anglorum, be,
# Nearest to during: before, throughout, after, since, over, in, through, until,
# Nearest to may: can, must, would, could, should, might, will, cannot,
# Nearest to other: various, these, different, others, several, all, subatomic, more,
# Nearest to d: kick, provable, leyte, shit, bis, fiberglass, horseshoe, obligated,
# Nearest to this: it, what, the, which, injunction, that, aleksandar, another,
# Nearest to by: saipan, kourou, aoun, hermaphrodite, phillips, through, under, deoxyribonucleic,
# Nearest to state: latitudes, hectic, aachen, courts, brisk, assembly, government, national,
# Nearest to history: life, list, widgets, pembroke, ganga, view, ointment, version,
# Nearest to called: named, considered, used, known, courant, fathoms, stepmania, foetus,
# Nearest to world: cakes, vietnam, civil, kate, finances, yeager, ellipsis, yourself,
# Nearest to they: we, you, he, there, she, chez, humans, ovid,
# Nearest to but: than, bethe, ergodic, though, and, see, forall, while,
# Average loss at step 32000: 3.017682
# Average loss at step 34000: 3.199523
# Average loss at step 36000: 3.192150
# Average loss at step 38000: 3.148453
# Average loss at step 40000: 3.155011
# Nearest to was: is, were, became, are, becomes, has, had, makes,
# Nearest to years: decades, days, months, centuries, year, times, eighteen, economists,
# Nearest to he: she, it, gob, they, heartbreak, sacrum, guang, ergonomics,
# Nearest to were: are, was, is, include, being, had, inlays, became,
# Nearest to during: in, throughout, before, after, over, since, despite, following,
# Nearest to may: can, must, should, could, might, will, would, cannot,
# Nearest to other: various, local, including, others, flirty, both, biz, khomeini,
# Nearest to d: b, ballads, bis, obligated, f, armada, horseshoe, muscat,
# Nearest to this: which, it, each, what, the, another, wealthier, injunction,
# Nearest to by: remus, deoxyribonucleic, geffen, saipan, when, aoun, upu, has,
# Nearest to state: latitudes, government, assembly, foibles, valign, territory, strolling, lattice,
# Nearest to history: period, ncr, list, ammanati, ganga, quantities, caesarion, mojave,
# Nearest to called: named, considered, used, known, referred, see, haihowak, dental,
# Nearest to world: vietnam, u, cold, european, cartagena, finances, hirsch, automorphism,
# Nearest to they: we, you, advertisers, he, there, humans, stirrups, badlands,
# Nearest to but: however, chasm, although, than, and, while, though, armalite,
# Average loss at step 42000: 3.211166
# Average loss at step 44000: 3.138038
# Average loss at step 46000: 3.139169
# Average loss at step 48000: 3.050366
# Average loss at step 50000: 3.056522
# Nearest to was: is, were, became, are, being, becomes, had, has,
# Nearest to years: decades, months, days, centuries, year, hours, times, minutes,
# Nearest to he: she, it, they, who, sedation, davidson, eventually, gob,
# Nearest to were: are, was, being, is, include, anglorum, have, be,
# Nearest to during: throughout, in, before, following, after, since, until, when,
# Nearest to may: can, should, might, must, could, would, will, cannot,
# Nearest to other: various, others, different, rather, both, subatomic, their, iud,
# Nearest to d: b, rudolph, irreducibly, matthews, comit, delle, simpson, photoelectric,
# Nearest to this: which, it, another, she, ncos, what, entrails, industrially,
# Nearest to by: under, aoun, when, without, angiosperms, thus, hermaphrodite, pavements,
# Nearest to state: latitudes, city, government, courts, church, nouvelle, constitution, foibles,
# Nearest to history: list, sometime, economy, origin, aga, amazed, neolithic, rains,
# Nearest to called: named, used, considered, featured, known, termed, facing, see,
# Nearest to world: vietnam, sonia, country, nation, cold, kreutzmann, kate, craggy,
# Nearest to they: we, you, he, there, she, chez, musings, becket,
# Nearest to but: although, and, than, or, halifax, though, peking, however,
# Average loss at step 52000: 3.087444
# Average loss at step 54000: 3.092931
# Average loss at step 56000: 2.911750
# Average loss at step 58000: 3.016051
# Average loss at step 60000: 3.047852
# Nearest to was: is, became, were, had, becomes, remained, are, has,
# Nearest to years: decades, months, days, centuries, year, times, weeks, hours,
# Nearest to he: she, it, they, who, nac, bleach, we, tease,
# Nearest to were: are, was, being, is, include, had, anglorum, marta,
# Nearest to during: before, throughout, in, after, when, following, until, since,
# Nearest to may: can, might, should, could, must, cannot, will, would,
# Nearest to other: others, various, fewer, certain, hur, rather, subatomic, different,
# Nearest to d: b, bis, tumbling, sidewise, elaine, investors, ther, diss,
# Nearest to this: it, which, the, another, aleksandar, she, what, a,
# Nearest to by: solitaire, under, through, weaving, deoxyribonucleic, meteoric, lorentz, milky,
# Nearest to state: coherent, government, pepin, mint, kingdom, states, aachen, nouvelle,
# Nearest to history: list, life, journal, origin, course, ripped, origins, period,
# Nearest to called: considered, termed, bouncer, named, referred, included, used, established,
# Nearest to world: country, vietnam, cold, thracian, nation, kreutzmann, story, battlestar,
# Nearest to they: we, you, he, she, there, proc, wads, humans,
# Nearest to but: and, although, than, though, however, while, altaic, unlike,
# Average loss at step 62000: 3.007703
# Average loss at step 64000: 2.918857
# Average loss at step 66000: 2.925476
# Average loss at step 68000: 2.964230
# Average loss at step 70000: 3.009073
# Nearest to was: is, were, became, becomes, makes, has, are, had,
# Nearest to years: months, decades, days, year, weeks, centuries, minutes, hours,
# Nearest to he: she, it, they, who, bleach, cassini, conjunct, davidson,
# Nearest to were: are, was, is, combi, include, be, anglorum, being,
# Nearest to during: throughout, in, until, before, after, following, when, at,
# Nearest to may: might, can, could, should, must, would, will, cannot,
# Nearest to other: various, hur, these, fewer, some, different, rather, certain,
# Nearest to d: b, horseshoe, cr, sidewise, bis, elaine, r, footballer,
# Nearest to this: which, it, another, that, ncos, what, a, fido,
# Nearest to by: aoun, auditum, hermaphrodite, eradicated, solitaire, for, incan, preferable,
# Nearest to state: government, states, pepin, aachen, church, mint, solved, parliament,
# Nearest to history: origin, list, journal, life, alleles, development, origins, ripped,
# Nearest to called: considered, termed, named, included, known, used, described, referred,
# Nearest to world: vietnam, u, protections, cold, country, sedation, contexts, girlfriends,
# Nearest to they: we, you, he, she, there, humans, it, these,
# Nearest to but: although, while, however, though, than, because, and, which,
# Average loss at step 72000: 2.941342
# Average loss at step 74000: 2.873273
# Average loss at step 76000: 2.994147
# Average loss at step 78000: 3.009952
# Average loss at step 80000: 2.841338
# Nearest to was: is, were, becomes, became, are, has, makes, had,
# Nearest to years: decades, months, days, year, centuries, weeks, minutes, times,
# Nearest to he: she, it, they, publicly, there, nobody, germanicus, verizon,
# Nearest to were: are, was, is, include, rifling, anglorum, had, various,
# Nearest to during: throughout, before, in, after, until, since, despite, at,
# Nearest to may: might, can, could, should, will, would, must, cannot,
# Nearest to other: various, fewer, numerous, different, including, others, certain, subatomic,
# Nearest to d: b, bis, horseshoe, pour, et, olives, darcy, unhelpful,
# Nearest to this: which, it, what, another, the, main, frazer, that,
# Nearest to by: aoun, deoxyribonucleic, hermaphrodite, borland, preferable, dependable, towards, auditum,
# Nearest to state: government, states, aachen, kingdom, celebration, curtius, choice, parliament,
# Nearest to history: list, kind, origin, origins, study, sometime, domicile, entrepreneurs,
# Nearest to called: considered, termed, named, used, houdini, known, practiced, amulets,
# Nearest to world: cold, vietnam, contexts, protections, testament, tsiolkovsky, automorphism, country,
# Nearest to they: we, you, there, he, she, badlands, others, filters,
# Nearest to but: although, though, and, than, however, see, or, tydings,
# Average loss at step 82000: 2.935313
# Average loss at step 84000: 2.891818
# Average loss at step 86000: 2.921455
# Average loss at step 88000: 2.940834
# Average loss at step 90000: 2.839504
# Nearest to was: is, were, became, becomes, are, had, being, remains,
# Nearest to years: decades, months, days, year, centuries, weeks, hours, minutes,
# Nearest to he: she, it, they, leibniz, milne, rium, lis, team,
# Nearest to were: are, was, combi, is, include, had, have, operate,
# Nearest to during: after, in, before, throughout, until, since, despite, at,
# Nearest to may: might, must, should, can, would, will, could, cannot,
# Nearest to other: different, various, fewer, others, many, certain, subatomic, cham,
# Nearest to d: b, pour, bis, rounded, unhelpful, oslo, intimidated, similarly,
# Nearest to this: it, which, another, what, the, a, aleksandar, programmatic,
# Nearest to by: through, aoun, hermaphrodite, txt, geffen, reinvented, thereby, preferable,
# Nearest to state: elder, airway, hilary, hamsun, albino, presence, coherent, aachen,
# Nearest to history: list, range, modern, portrait, variety, signet, study, view,
# Nearest to called: considered, named, termed, known, used, described, amulets, houdini,
# Nearest to world: vietnam, nation, contexts, tsiolkovsky, cold, country, challenge, thrusting,
# Nearest to they: we, you, he, there, she, it, filters, solent,
# Nearest to but: though, however, although, and, unlike, than, like, see,
# Average loss at step 92000: 2.888906
# Average loss at step 94000: 2.887577
# Average loss at step 96000: 2.712861
# Average loss at step 98000: 2.461087
# Average loss at step 100000: 2.709698
# Nearest to was: is, became, were, remains, are, remained, makes, had,
# Nearest to years: months, decades, days, year, weeks, hours, centuries, minutes,
# Nearest to he: she, it, they, who, coconut, germanicus, cassini, dyeing,
# Nearest to were: are, was, combi, have, being, include, sorties, had,
# Nearest to during: throughout, in, since, after, despite, at, assesses, until,
# Nearest to may: might, should, can, could, must, would, will, cannot,
# Nearest to other: various, individual, different, earlier, fewer, others, iud, hur,
# Nearest to d: b, tumbling, investors, rabbis, oppenheimer, olives, bmx, illegality,
# Nearest to this: which, another, some, the, it, labelling, what, diff,
# Nearest to by: aoun, through, via, turk, deoxyribonucleic, musik, without, hermaphrodite,
# Nearest to state: states, aachen, charge, mint, tornadoes, latitudes, choice, pepin,
# Nearest to history: origins, life, list, illustration, development, eustace, culture, career,
# Nearest to called: named, considered, termed, used, described, referred, known, amulets,
# Nearest to world: vietnam, cold, contexts, thrusting, city, savannas, u, kreutzmann,
# Nearest to they: we, you, he, she, there, filters, i, steamer,
# Nearest to but: and, however, though, although, alexandrovna, while, until, or,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
